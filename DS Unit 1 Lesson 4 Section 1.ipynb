# %% [markdown]
# %% HTML
#
# <html>
#
# <head>
# <meta http-equiv=Content-Type content="text/html; charset=windows-1252">
# <meta name=Generator content="Microsoft Word 14 (filtered)">
# <style>
# <!--
#  /* Font Definitions */
#  @font-face
# 	{font-family:Calibri;
# 	panose-1:2 15 5 2 2 2 4 3 2 4;}
# @font-face
# 	{font-family:Tahoma;
# 	panose-1:2 11 6 4 3 5 4 4 2 4;}
#  /* Style Definitions */
#  p.MsoNormal, li.MsoNormal, div.MsoNormal
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:10.0pt;
# 	margin-left:0in;
# 	line-height:100%;
# 	font-size:12.0pt;
# 	color:black;
# 	font-weight:normal;
# 	font-family:"Calibri","sans-serif";}
# h1
# 	{mso-style-link:"Heading 1 Char";
# 	margin-right:0in;
# 	margin-left:0in;
# 	font-size:24.0pt;
# 	font-family:"Calibri","sans-serif";}
# h2
# 	{mso-style-link:"Heading 2 Char";
# 	margin-right:0in;
# 	margin-left:0in;
# 	font-size:18.0pt;
# 	font-family:"Calibri","sans-serif";}
# h3
# 	{mso-style-link:"Heading 3 Char";
# 	margin-right:0in;
# 	margin-left:0in;
# 	font-size:13.5pt;
# 	font-family:"Calibri","sans-serif";}
# h4
# 	{mso-style-link:"Heading 4 Char";
# 	margin-right:0in;
# 	margin-left:0in;
# 	font-size:12.0pt;
# 	font-family:"Calibri","sans-serif";}
# p.MsoCaption, li.MsoCaption, div.MsoCaption
# 	{margin-top:0in;
# 	margin-right:0in;
# 	margin-bottom:10.0pt;
# 	margin-left:0in;
# 	font-size:9.0pt;
# 	font-family:"Calibri","sans-serif";
# 	color:#4F81BD;
# 	font-weight:bold;}
# p.MsoAcetate, li.MsoAcetate, div.MsoAcetate
# 	{mso-style-link:"Balloon Text Char";
# 	margin:0in;
# 	margin-bottom:.0001pt;
# 	font-size:8.0pt;
# 	font-family:"Tahoma","sans-serif";}
# span.Heading1Char
# 	{mso-style-name:"Heading 1 Char";
# 	mso-style-link:"Heading 1";
# 	font-family:"Times New Roman","serif";
# 	font-weight:bold;}
# span.Heading2Char
# 	{mso-style-name:"Heading 2 Char";
# 	mso-style-link:"Heading 2";
# 	font-family:"Times New Roman","serif";
# 	font-weight:bold;}
# span.Heading3Char
# 	{mso-style-name:"Heading 3 Char";
# 	mso-style-link:"Heading 3";
# 	font-family:"Times New Roman","serif";
# 	font-weight:bold;}
# span.Heading4Char
# 	{mso-style-name:"Heading 4 Char";
# 	mso-style-link:"Heading 4";
# 	font-family:"Times New Roman","serif";
# 	font-weight:bold;}
# span.BalloonTextChar
# 	{mso-style-name:"Balloon Text Char";
# 	mso-style-link:"Balloon Text";
# 	font-family:"Tahoma","sans-serif";}
# p.msochpdefault, li.msochpdefault, div.msochpdefault
# 	{mso-style-name:msochpdefault;
# 	margin-right:0in;
# 	margin-left:0in;
# 	font-size:12.0pt;
# 	font-family:"Calibri","sans-serif";}
# p.msopapdefault, li.msopapdefault, div.msopapdefault
# 	{mso-style-name:msopapdefault;
# 	margin-right:0in;
# 	margin-bottom:10.0pt;
# 	margin-left:0in;
# 	line-height:115%;
# 	font-size:12.0pt;
# 	font-family:"Times New Roman","serif";}
# .MsoChpDefault
# 	{font-size:10.0pt;
# 	font-family:"Calibri","sans-serif";}
# @page WordSection1
# 	{size:8.5in 11.0in;
# 	margin:1.0in 1.0in 1.0in 1.0in;}
# div.WordSection1
# 	{page:WordSection1;}
# -->
# </style>
#
# </head>
#
# <body lang=EN-US>
#
# <div class=WordSection1>
#
# <h1>
#     <span>DS Unit 1 Lesson 4 Section 1
#     </span>
# </h1>
#
# <p class=MsoNormal>
#     <span>Frendy Excellent, Thinkful, 4/15/2019</span>
# </p>
#
# <p class=MsoNormal>
#     <span>
#         Problem: Does a new supplement help people sleep better? Answer: Control: Existing Supplement A and Variable: New Supplement B Randomly give existing version of supplement to one group of patients of a particular health care provider. Randomly give the new version of supplement to another group of patients of another health care provider. Collect a random sample, until patient count is large enough, based on confidence level and statistical power estimates. Null Hypothesis: There is no significant difference in sleeping effects between supplements. Null Hypothesis: There is a significant  difference in sleeping effects between supplements. Perhaps two-tailed t-test reveals that there is no difference between supplements (accept null hypothesis). Perhaps, working up late in the morning could be monitored?
#     </span>
# </p>
#
# <p class=MsoNormal>
#     <span>
#         Problem: Will new uniforms help a gym's business? Answer: Control: uniform color A, Variable: new color B. Select two  groups of randomly selected gym locations: group X and group Y. Assign existing color A to group X, assign color B to group Y.  Collect a random sample, until sign-up count is large enough, based on confidence level and statistical power estimates. Null: There is no significant difference between colors. Alternative: There is a significant difference between colors. Perhaps, new color improves signing up new customers. Measure error rate in data entry as volume of sign-ups increases.
#     </span>
# </p>
#
# <p class=MsoNormal>
#     <span>
#         Problem: Will a new homepage improve my online exotic pet rental business? Answer: Control: existing home page, variable: new home page Serve control, at random, odd IP address. Serve variable, at random, even IP address. Null Hypopthesis: There is no significant difference between the home page versions. Alternative Hypopthesis: There is a significant difference between the home page versions. New home page version performs better than existing version. Observe the most frequent location that visitors click on the new page.
#     </span>
# </p>
#
# <p class=MsoNormal>
#     <span>
#         Problem:If I put 'please read' in the email subject will more people read my emails? Answer: Control: Email without &quot;please read&quot; in the subject, variable: Email with 'please read' in the subject Split mailing list into two groups (50:50) of random recipients. Send control email to one random group of recipients from mailing list. Send variable email to other random group of recipients from mailing list. Null Hypopthesis: There is no significant difference between the versions of email subjects. Alternative Hypopthesis: There is a significant difference between the versions of email subjects. Perhaps, please read in header results in more recipients reading the email. Perhaps, measure the time it takes to obtain a response.
#     </span>
# </p>
#
# </div>
#
# </body>
#
# </html>
