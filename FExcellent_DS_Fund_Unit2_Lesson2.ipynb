# %% [markdown]
# ## DS Fund Unit 2 Lesson 2 Section 1

# %%
import requests
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd 
# %matplotlib inline

# %%
plt.plot([0, 1, 2, 3],[0,3,7,14])
plt.show()

# %%
# Make the random function consistent and replicable.
np.random.seed(1221)

# Make a blank data frame.
df = pd.DataFrame()

# Add a column of random numbers between 0 and 1.
df['rand'] = np.random.rand(100)
df['rand_sq'] = df['rand'] ** 2
df['rand_shift'] = df['rand'] + 2

# When creating a data frame an index column of counts is created, counting from 0.
# Here we do a few transforms on that index to create some extra columns.
df['counts_sq'] = df.index ** 2 
df['counts_sqrt'] = np.sqrt(df.index)

# %%
plt.plot(df['rand'])
plt.show()

# %%
plt.plot(df['rand'], color='purple')
plt.plot(df['rand_shift'], color='green')
plt.ylim([-0.1, 3.1])
plt.ylabel('Values')
plt.title('Random Series')
plt.show()

# %%
plt.scatter(
    x=df['rand'],
    y=df['rand_sq'],
    color='purple',
    marker='x', s=10
)
plt.scatter(
    x=df['rand'],
    y=df['rand_shift'],
    color='green',
    marker='x', s=10
)
plt.show()

# %%
_2_pi = 2 * np.pi
x_pi = np.arange(0, _2_pi,0.05)
sin_x_pi = np.sin(x_pi)

plt.scatter(
    x=x_pi,
    y=sin_x_pi,
    color="Blue",
    marker='x',
    s=12
    )

plt.plot(x_pi,
         sin_x_pi,
         color="Yellow"
        )

plt.title("Signal Monitoring")
plt.xlabel('Distance')
plt.ylabel('Signal Level')
plt.show()

# %%
df.plot(kind='scatter', x='counts_sq',y= 'counts_sqrt')
df.plot(kind='line')
plt.show()

# %% [markdown]
# ## DS Fund Unit 2 Lesson 2 Section 2

# %%
# Make the random function consistent and replicable.
np.random.seed(1221)

# Make a blank data frame.
df = pd.DataFrame()
df['rand'] = np.random.rand(100)  # Add a column of random numbers between 0 and 1.
df['rand_sq'] = df['rand'] ** 2
df['rand_shift'] = df['rand'] + 2

# When creating a data frame an index column of counts is created, counting from 0.
# Here we do a few transforms on that index to create some extra columns.
df['counts_sq'] = df.index ** 2 
df['counts_sqrt'] = np.sqrt(df.index)

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(df['rand'], color='purple')
plt.ylabel('Values')
plt.title('Random Series')

plt.subplot(1, 2, 2)
plt.plot(df['rand_shift'], color='green')
plt.ylabel('Shifted Values')
plt.title('Shifted Series')
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(df['rand'], color='purple')
plt.ylabel('Values')
plt.title('Random Series')

plt.subplot(1, 2, 2)
plt.scatter(x = df['rand_sq'], y = df['rand'], color='green')
plt.ylabel('Squared Values')
plt.title('Squared Series')

plt.tight_layout()
plt.show()

# %%
_2_pi = 2 * np.pi
x_pi = np.arange(0, _2_pi,0.05)
sin_x_pi = np.sin(x_pi)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(
    x=x_pi,
    y=sin_x_pi,
    color="Blue",
    marker='x',
    s=12
    )
plt.title("Signal Monitoring")
plt.xlabel('Distance')
plt.ylabel('Signal Level')

plt.subplot(1, 2, 2)
plt.plot(x_pi,
         sin_x_pi,
         color="Green"
        )

plt.title("Signal Monitoring")
plt.xlabel('Distance')
plt.ylabel('Signal Level')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## DS Fund Unit 2 Lesson 2 Section 3

# %%
# Generate 1000 random values.
x = np.random.normal(10, 5, 10**7)
y = np.random.normal(15, 5, 10**5)
# Plot them as a histogram.


plt.figure(figsize=(10, 5),facecolor='yellow')
plt.subplot(1, 2, 1)
plt.hist(
    x,
    density=True,
    bins=np.arange(-10, 40,.1),
    alpha=.2,     
    color='green'
    )
plt.title('Manually setting bin placement')
plt.xlabel('Random Values')
plt.ylabel('Signal Level')

plt.subplot(1, 2, 2)
plt.hist(
    y,
    density=True,
    bins=np.arange(-10, 40,.1),
    alpha=.5,     
    color='red'
    )
plt.title('Manually setting bin placement')
plt.xlabel('Random Values')
plt.ylabel('Signal Level')

plt.show()

# %%
# Same data, this time normed.
plt.hist(x, density=True, color='blue', bins=np.arange(-10, 40,.1), alpha=.2) 
plt.hist(y, density=True, color='red', bins=np.arange(-10, 40,.1), alpha=.5)
plt.title('Normalized histograms')
plt.xlabel('Random Values')

plt.show()

# %%
plt.figure(figsize=(10, 5),facecolor='yellow')
plt.subplot(1, 2, 1)
# Set the random seed to keep the example consistent.
np.random.seed(111)
# Sample data.
x = np.random.normal(10, 5, 10**3)
# Generate and display the box plot.
plt.boxplot(x)
plt.subplot(1, 2, 2)
# Set the random seed to keep the example consistent.
np.random.seed(111)
# Sample data.
y = np.random.normal(10, 5, 10**2)
# Generate and display the box plot.
plt.boxplot(y)
plt.show()

# %% [markdown]
# ## DS Fund Unit 2 Lesson 2 Section 4

# %% [markdown]
# Scenario for following graphs: Hurricane Katrina is on its way. I have been tasked with identifying the vulnerale citizens to facilitate emergency preparation. Data obtained from census.gov site. Data points include 63 parishes total for the state of Louisiana. Three categories of data (details on census.gov): percent disability, percent below poverty level, and percent without vehicles. Approach: Use bubble chart only for percent disability, use bar charts for all three categories (percent disability, percent below poverty level, and percent without vehicles). Conclusion: At first glance, the bubble charts are not that helpful for prioritizing disability evacuation. The bar charts seem to indicate that pverty level and lack of vehicles move together, which makes sense (focus on helping evacuate the poorest sector of the population). Finally, an experimental donut is displayed at the end (I don't think it's useful for this work). "Vulnerability_LA_Parishes_v9.csv" file is on same GitHub folder as this notebook.

# %%
#res = requests.get("https://api.census.gov/data/2016/acs/acs5/profile?get=DP02_0071PE,DP03_0128PE,DP04_0058PE,NAME&for=county:*&in=state:22")
#j = res.json()
#print(j)
#df = pd.DataFrame(j)
#print(df.head())
#filename ="Vulnerability_LA_Parishes_ori.csv"
#df.to_csv(filename)

# %%
#j_temp = pd.read_json("ACS_2016_Profile_Variables.json")
#print(j_temp)
#df2 = pd.DataFrame(j_temp)
#print(df2.head())
#filename ="ACS_2016_Profile_Variables.csv"
#df2.to_csv(filename)

# %%
la_data = pd.read_csv("Vulnerability_LA_Parishes_v9.csv")
#print(la_data)
df_la = pd.DataFrame(la_data)
df_la_index = df_la['Parish']
df_la.index = df_la_index

# %%
df_la.head()
# Out:
#                               Parish  Sate  County  0  Dis_Pct  Bel_Pov_Pct  \
# Parish
# Acadia Parish          Acadia Parish    22       1  1     18.0         20.6
# Allen Parish            Allen Parish    22       3  2     22.0         15.9
# Ascension Parish    Ascension Parish    22       5  3     11.6         11.5
# Assumption Parish  Assumption Parish    22       7  4     19.6         18.4
# Avoyelles Parish    Avoyelles Parish    22       9  5     18.2         23.1
#
#                    No_Veh_Pct
# Parish
# Acadia Parish             7.7
# Allen Parish              8.2
# Ascension Parish          3.7
# Assumption Parish         7.7
# Avoyelles Parish          9.4

# %%
plt.figure(figsize=(10, 5),facecolor='yellow')

plt.subplot(1, 2, 1)
df_la_temp = df_la[df_la['0'] <= 16]
df_la_1 = df_la_temp
a1 = plt.scatter(df_la_1.index, df_la_1[['Dis_Pct']],s=df_la_1['Dis_Pct']*50, alpha=0.5)
a1.axes.xaxis.set_tick_params(rotation=90)

plt.subplot(1, 2, 2)
df_la_temp = df_la[df_la['0'] > 16]
df_la_2 = df_la_temp[df_la_temp['0'] <= 32]
a2 = plt.scatter(df_la_2.index, df_la_2[['Dis_Pct']],s=df_la_2['Dis_Pct']*50, alpha=0.5)
a2.axes.xaxis.set_tick_params(rotation=90)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5),facecolor='yellow')

plt.subplot(1, 2, 1)
df_la_temp = df_la[df_la['0'] > 32]
df_la_1 = df_la_temp[df_la_temp['0'] <= 48]
a1 = plt.scatter(df_la_1.index, df_la_1[['Dis_Pct']],s=df_la_1['Dis_Pct']*50, alpha=0.5)
a1.axes.xaxis.set_tick_params(rotation=90)

plt.subplot(1, 2, 2)
df_la_temp = df_la[df_la['0'] >= 48]
df_la_2 = df_la_temp[df_la_temp['0'] <=64]
a2 = plt.scatter(df_la_2.index, df_la_2[['Dis_Pct']],s=df_la_2['Dis_Pct']*50, alpha=0.5)
a2.axes.xaxis.set_tick_params(rotation=90)
plt.tight_layout()
plt.show()

# %%
df_la_temp = df_la[df_la['0'] <= 16]
df_la_1 = df_la_temp
df_la_1[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True,subplots='True',layout=(2, 2))
df_la_1[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True)
df_la_1[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=False)
plt.tight_layout()
plt.show()

# %%
df_la_temp = df_la[df_la['0'] > 16]
df_la_2 = df_la_temp[df_la_temp['0'] <= 32]
df_la_2[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True,subplots='True',layout=(2, 2))
df_la_2[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True)
df_la_2[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=False)
plt.tight_layout()
plt.show()

# %%
df_la_temp = df_la[df_la['0'] > 32]
df_la_1 = df_la_temp[df_la_temp['0'] <= 48]
df_la_1[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True,subplots='True',layout=(2, 2))
df_la_1[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True)
df_la_1[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=False)
plt.tight_layout()
plt.show()

# %%
df_la_temp = df_la[df_la['0'] >= 48]
df_la_2 = df_la_temp[df_la_temp['0'] <=64]
df_la_2[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True,subplots='True',layout=(2, 2))
df_la_2[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=True)
df_la_2[['Dis_Pct','Bel_Pov_Pct','No_Veh_Pct']].plot(kind='bar', stacked=False)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 5), subplot_kw=dict(aspect="equal"))

my_index = df_la_index
df_la_temp = df_la[df_la['0'] <= 16]
df_la_1 = df_la_temp
data = df_la_1['Dis_Pct']

wedges, texts = ax.pie(data, wedgeprops=dict(width=0.5), startangle=-40)

bbox_props = dict(boxstyle="square,pad=0.3", fc="w", ec="k", lw=0.72)
kw = dict(xycoords='data', textcoords='data', arrowprops=dict(arrowstyle="-"),
          bbox=bbox_props, zorder=0, va="center")

for i, p in enumerate(wedges):
    ang = (p.theta2 - p.theta1)/2. + p.theta1
    y = np.sin(np.deg2rad(ang))
    x = np.cos(np.deg2rad(ang))
    horizontalalignment = {-1: "right", 1: "left"}[int(np.sign(x))]
    connectionstyle = "angle,angleA=0,angleB={}".format(ang)
    kw["arrowprops"].update({"connectionstyle": connectionstyle})
    ax.annotate(my_index[i], xy=(x, y), xytext=(1.35*np.sign(x), 1.4*y),
                 horizontalalignment=horizontalalignment, **kw)

ax.set_title("Population Disability Status (%)",fontdict={"fontsize": 20},color="b")
plt.tight_layout()
plt.show()
